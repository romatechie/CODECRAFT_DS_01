# %% [markdown]
# ## TASK - 01
# | Create a bar chart or histogram to visualize the distribution of a categorical or continuous variable, such as the distribution of ages or genders in a population.
#
# Sample Dataset :- https://data.worldbank.org/indicator/SP.POP.TOTL
#
# - Intern Name : ROMA JAISWAL
# - Internship By : CODE CRAFT
# - Domain : DATA SCIENCE

# %% [markdown]
# ##### Introduction
#
# In this task, we aim to ***visualize the distribution of a categorical or continuous variable using a bar chart or histogram***. Visualization helps in understanding the underlying patterns and trends in the data, making it easier to interpret and analyze. For this purpose, we will use a sample dataset from the World Bank, which provides information about the total population of various countries. By creating visual representations such as bar charts or histograms, we can gain insights into the distribution of population sizes or other demographic variables, such as age or gender, within a population. This task is a fundamental step in exploratory data analysis and is essential for effective data-driven decision making.

# %% [markdown]
# Step 1 : Importing the basic packages required

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('API_SP.POP.TOTL_DS2.csv',  encoding='utf-8')
df.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54922.0      55578.0      56320.0      57002.0      57619.0
# 1  130075728.0  133534923.0  137171659.0  140945536.0  144904094.0
# 2    9035043.0    9214083.0    9404406.0    9604487.0    9814318.0
# 3   97630925.0   99706674.0  101854756.0  104089175.0  106388440.0
# 4    5231654.0    5301583.0    5354310.0    5408320.0    5464187.0
#
#           1965  ...         2015         2016         2017         2018  \
# ...

# %%
df.tail()
# Out:
#      Country Name Country Code     Indicator Name Indicator Code        1960  \
# 261        Kosovo          XKX  Population, total    SP.POP.TOTL    984846.0
# 262   Yemen, Rep.          YEM  Population, total    SP.POP.TOTL   5532301.0
# 263  South Africa          ZAF  Population, total    SP.POP.TOTL  16440172.0
# 264        Zambia          ZMB  Population, total    SP.POP.TOTL   3153729.0
# 265      Zimbabwe          ZWE  Population, total    SP.POP.TOTL   3809389.0
#
#            1961        1962        1963        1964        1965  ...  \
# 261   1011421.0   1036950.0   1062737.0   1090270.0   1120168.0  ...
# 262   5655232.0   5782221.0   5911135.0   6048006.0   6195593.0  ...
# 263  16908035.0  17418522.0  17954564.0  18511361.0  19089380.0  ...
# 264   3254086.0   3358099.0   3465907.0   3577017.0   3692086.0  ...
# 265   3930401.0   4055959.0   4185877.0   4320006.0   4458462.0  ...
#
#            2015        2016        2017        2018        2019        2020  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 69 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    266 non-null    object
#  1   Country Code    266 non-null    object
#  2   Indicator Name  266 non-null    object
#  3   Indicator Code  266 non-null    object
#  4   1960            264 non-null    float64
#  5   1961            264 non-null    float64
#  6   1962            264 non-null    float64
#  7   1963            264 non-null    float64
#  8   1964            264 non-null    float64
#  9   1965            264 non-null    float64
#  10  1966            264 non-null    float64
#  11  1967            264 non-null    float64
#  12  1968            264 non-null    float64
#  13  1969            264 non-null    float64
#  14  1970            264 non-null    float64
#  15  1971            264 non-null    float64
#  16  1972            264 non-null    float64
# ...

# %%
df.describe()
# Out:
#                1960          1961          1962          1963          1964  \
# count  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02
# mean   1.154023e+08  1.170070e+08  1.191678e+08  1.218381e+08  1.245322e+08
# std    3.616526e+08  3.661347e+08  3.727681e+08  3.813687e+08  3.900162e+08
# min    2.715000e+03  2.970000e+03  3.264000e+03  3.584000e+03  3.922000e+03
# 25%    5.152028e+05  5.255230e+05  5.363018e+05  5.475875e+05  5.593638e+05
# 50%    3.659633e+06  3.747132e+06  3.831900e+06  3.919710e+06  4.010150e+06
# 75%    2.686293e+07  2.761326e+07  2.837302e+07  2.915448e+07  2.995223e+07
# max    3.021513e+09  3.062768e+09  3.117372e+09  3.184063e+09  3.251253e+09
#
#                1965          1966          1967          1968          1969  \
# count  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02
# mean   1.272581e+08  1.301037e+08  1.329570e+08  1.358851e+08  1.389115e+08
# ...

# %%
df_final = df.drop(['Country Code',	'Indicator Name',	'Indicator Code'], axis=1)

# %%
select_country = 'Afghanistan'


country_data = df_final[df_final['Country Name'] == select_country]


years = country_data.columns[2:].astype(int)
population = country_data.iloc[:, 2:].values.flatten()

plt.figure(figsize=(5, 3))
plt.bar(years, population, color='skyblue')
plt.xlabel('Year')
plt.ylabel('Population')
plt.title(f'Population of {select_country} Over the Years')
# Out:
# Text(0.5, 1.0, 'Population of Afghanistan Over the Years')

# %%
plt.hist(population, bins=20, color='green', edgecolor='yellow')
plt.show()

# %%
plt.figure(figsize=(8, 4))
plt.plot(years, population, linestyle='-', color='red')
plt.xlabel('Year')
plt.ylabel('Population')
plt.title(f'Population of {select_country} Over the Years')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Thank you, In this task we are selecting a specfic country for example Afghanistan and then analyzing it's population growth/fall using the Histogram,Bar Chart and Line Chart.
